# %%
# My additions: Plants which the prey eat and they grow in energy, hunters attack the predators, and prey run away from predators

from mesa import Agent, Model
from mesa.datacollection import DataCollector
from mesa.experimental.jupyter_viz import JupyterViz
from mesa.time import RandomActivation
import seaborn as sns
from mesa.space import MultiGrid
import random
from mesa.visualization.modules import CanvasGrid
from mesa.visualization.ModularVisualization import ModularServer
from mesa.visualization.modules import ChartModule


PLACEHOLDER_POS = (0, 0)
HEIGHT = 10
WIDTH = 10
PREY = 5
PREDATOR = 10
PLANT = 10
HUNTER = 10

class Plant(Agent):
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.energy = 50
    
    def grow(self):
        self.energy += 1

    def step(self):
        if self.pos is None:
            return
        self.grow()

class Prey(Agent):
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.energy = 100

    def move(self):
        possible_steps = self.model.grid.get_neighborhood(
            self.pos, moore=True, include_center=False
        )
        predator_agents = [agent for agent in possible_steps if
                       isinstance(agent, Predator)]
        if predator_agents:
            predator_to_run_from = random.choice(predator_agents)
            possible_steps.remove(predator_to_run_from)
        new_position = random.choice(possible_steps)
        self.model.grid.move_agent(self, new_position)

    def eat(self):
        plant_neighbors = self.model.grid.get_cell_list_contents(
            [self.pos]
        )
        plant_agents = [agent for agent in plant_neighbors if
                       isinstance(agent, Plant)]
        if plant_agents:
            plant_to_eat = random.choice(plant_agents)
            self.model.schedule.remove(plant_to_eat)
            self.model.grid.remove_agent(plant_to_eat)
            self.energy += plant_to_eat.energy

    def breed(self):
        if self.energy >= 200:
            self.energy -= 100
            new_prey = Prey(self.model.next_id(), self.model)
            self.model.grid.place_agent(new_prey, PLACEHOLDER_POS)
            self.model.grid.move_to_empty(new_prey)
            self.model.schedule.add(new_prey)

    def step(self):
        # if this agent was removed from the grid, don't step. this is
        # important because if an agent is removed from the RandomActivation
        # scheduler before it has stepped, it will still step one last time
        if self.pos is None:
            return
        self.move()
        self.eat()
        self.breed()
        self.energy -= 1


class Hunter(Agent):
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.energy = 100
        self.just_caught = False
        self.animals_caught = 0

    def move(self):
        if self.just_caught:
            self.just_caught = False
            return
        possible_steps = self.model.grid.get_neighborhood(
            self.pos, moore=True, include_center=False
        )
        predator_agents = [agent for agent in possible_steps if
                       isinstance(agent, Predator)]
        if predator_agents:
            predator_to_attack = random.choice(predator_agents)
            new_position = predator_to_attack.pos
        else:
            new_position = random.choice(possible_steps)
            self.model.grid.move_agent(self, new_position)

    def attack(self):
        predator_neighbors = self.model.grid.get_cell_list_contents(
            [self.pos]
        )
        predator_agents = [agent for agent in predator_neighbors if
                       isinstance(agent, Prey)]
        if predator_agents:
            predator_to_eat = random.choice(predator_agents)
            self.model.schedule.remove(predator_to_eat)
            self.model.grid.remove_agent(predator_to_eat)
            self.energy += predator_to_eat.energy
            self.just_caught = True
            self.animals_caught += 1

    def step(self):
        self.move()
        self.attack()
        self.energy -= 1

class Predator(Agent):
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.energy = 100

    def move(self):
        possible_steps = self.model.grid.get_neighborhood(
            self.pos, moore=True, include_center=False
        )
        hunter_agents = [agent for agent in possible_steps if
                       isinstance(agent, Hunter)]
        if hunter_agents:
            hunter_to_run_from = random.choice(hunter_agents)
            possible_steps.remove(hunter_to_run_from)
        new_position = random.choice(possible_steps)
        self.model.grid.move_agent(self, new_position)

    def eat(self):
        prey_neighbors = self.model.grid.get_cell_list_contents(
            [self.pos]
        )
        prey_agents = [agent for agent in prey_neighbors if
                       isinstance(agent, Prey)]
        if prey_agents:
            prey_to_eat = random.choice(prey_agents)
            self.model.schedule.remove(prey_to_eat)
            self.model.grid.remove_agent(prey_to_eat)
            self.energy += 100

    def breed(self):
        if self.energy >= 200:
            self.energy -= 100
            new_predator = Predator(self.model.next_id(), self.model)
            self.model.grid.place_agent(new_predator, PLACEHOLDER_POS)
            self.model.grid.move_to_empty(new_predator)
            self.model.schedule.add(new_predator)

    def step(self):
        if self.pos is None:
            return
        self.move()
        self.eat()
        self.breed()
        self.energy -= 1

class PreyPredatorModel(Model):
    def __init__(self, height, width, prey_count, predator_count, plant_count, hunter_count):
        super().__init__()
        self.current_id = 0
        self.height = height
        self.width = width
        self.grid = MultiGrid(height, width, torus=True)
        self.schedule = RandomActivation(self)
        self.running = True

        for i in range(prey_count):
            prey = Prey(self.next_id(), self)
            self.grid.place_agent(prey, PLACEHOLDER_POS)
            self.grid.move_to_empty(prey)
            self.schedule.add(prey)

        for i in range(predator_count):
            predator = Predator(self.next_id(), self)
            self.grid.place_agent(predator, PLACEHOLDER_POS)
            self.grid.move_to_empty(predator)
            self.schedule.add(predator)

        for i in range(plant_count):
            plant = Plant(self.next_id(), self)
            self.grid.place_agent(plant, PLACEHOLDER_POS)
            self.grid.move_to_empty(plant)
            self.schedule.add(plant)

        for i in range(hunter_count):
            hunter = Hunter(self.next_id(), self)
            self.grid.place_agent(hunter, PLACEHOLDER_POS)
            self.grid.move_to_empty(hunter)
            self.schedule.add(hunter)
        
        self.datacollector = DataCollector(model_reporters={
            "Prey": lambda m: sum(isinstance(agent, Prey) for agent in m.schedule.agents),
            "Predator": lambda m: sum(isinstance(agent, Predator) for agent in m.schedule.agents),
            "Plant": lambda m: sum(isinstance(agent, Plant) for agent in m.schedule.agents),
            "Hunter": lambda m: sum(isinstance(agent, Hunter) for agent in m.schedule.agents),
            }, agent_reporters={
            "Prey": "prey",
            "Predator": "predator",
            "Plant": "plant",
            "Hunter": "hunter",
            "Animals Caught": "animals_caught"
        }
        )

    def step(self):
        self.datacollector.collect(self)
        self.schedule.step()

def main():
    model = PreyPredatorModel(height=HEIGHT, width=WIDTH, prey_count=PREY, plant_count=PLANT, hunter_count=HUNTER,
                                predator_count=PREDATOR)

    for i in range(100):
        model.step()
        # Print population counts
        prey_count = sum(
            isinstance(agent, Prey) for agent in model.schedule.agents)
        predator_count = sum(
            isinstance(agent, Predator) for agent in model.schedule.agents)
        plant_count = sum(
            isinstance(agent, Plant) for agent in model.schedule.agents)
        hunter_count = sum(
            isinstance(agent, Hunter) for agent in model.schedule.agents)
        animals_caught = sum(agent.animals_caught for agent in model.schedule.agents if isinstance(agent, Hunter))
        print(f"After step {i}: Prey={prey_count}, Predators={predator_count}, Plants={plant_count}, Hunters={hunter_count}, Animals caught={animals_caught}")

        # prey = model.datacollector.get_agent_vars_dataframe()
        # g = sns.lineplot(data=prey, x="Step", y="Prey", ci=None)
    
        
if __name__ == '__main__':
    main()

def agent_portrayal(agent):
    if isinstance(agent, Predator):
        portrayal = {"Shape": "circle", "Color": "red"}
    elif isinstance(agent, Prey):
        portrayal = {"Shape": "circle", "Color": "blue"}
    elif isinstance(agent, Plant):
        portrayal = {"Shape": "rect", "Color": "green"}
    elif isinstance(agent, Hunter):
        portrayal = {"Shape": "rect", "Color": "orange"}
    else:
        return None
    return portrayal

model_params ={
        "height": HEIGHT,
        "width": WIDTH,
        "prey_count": PREY,
        "predator_count": PREDATOR,
        "plant_count": PLANT,
        "hunter_count": HUNTER
    }
page = JupyterViz(
    PreyPredatorModel,
    model_params,
    measures=["Prey", "Predator", "Plant", "Hunter"],
    name="Predator/Prey Model",
    agent_portrayal=agent_portrayal,
)
# This is required to render the visualization in the Jupyter notebook
page
# Out:
# After step 0: Prey=4, Predators=10, Plants=10, Hunters=10, Animals caught=1
# After step 1: Prey=4, Predators=10, Plants=10, Hunters=10, Animals caught=1
# After step 2: Prey=4, Predators=10, Plants=10, Hunters=10, Animals caught=1
# After step 3: Prey=1, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 4: Prey=1, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 5: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 6: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 7: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 8: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 9: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 10: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 11: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 12: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 13: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 14: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 15: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 16: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 17: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 18: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 19: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 20: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 21: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 22: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 23: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 24: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 25: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 26: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 27: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 28: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 29: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 30: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 31: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 32: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 33: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 34: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 35: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 36: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 37: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 38: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 39: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 40: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 41: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 42: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 43: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 44: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 45: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 46: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 47: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 48: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 49: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 50: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 51: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 52: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 53: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 54: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 55: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 56: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 57: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 58: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 59: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 60: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 61: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 62: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 63: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 64: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 65: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 66: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 67: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 68: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 69: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 70: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 71: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 72: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 73: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 74: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 75: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 76: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 77: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 78: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 79: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 80: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 81: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 82: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 83: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 84: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 85: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 86: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 87: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 88: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 89: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 90: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 91: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 92: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 93: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 94: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 95: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 96: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 97: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 98: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# After step 99: Prey=0, Predators=10, Plants=10, Hunters=10, Animals caught=4
# Cannot show ipywidgets in text
